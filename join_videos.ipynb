# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/VIDEOS
# Out:
# /content/gdrive/MyDrive/VIDEOS

# %%
# !ls
# Out:
#  FHD0002.MOV   FHD0011.MOV	   FHD0023.MOV	  GOPR0511.MP4
#  FHD0003.MOV   FHD0012.MOV	   FHD0024.MOV	  GP010508.MP4
#  FHD0004.MOV   FHD0014.MOV	   FHD0025.MOV	  join_videos.ipynb
#  FHD0005.MOV   FHD0016.MOV	   FHD0026.MOV	  mylist.txt
#  FHD0006.MOV  'FHD0021b_(1).MOV'   FHD0027.MOV	  nv-codec-headers
#  FHD0007.MOV  'FHD0021b_(2).MOV'   FHD0028.MOV	  output.mp4
#  FHD0008.MOV  'FHD0021b_(3).MOV'   GOPR0508.MP4   rapida.mp4
#  FHD0009.MOV   FHD0021.MOV	   GOPR0509.MP4
#  FHD0010.MOV   FHD0022.MOV	   GOPR0510.MP4

# %%
#Create File List
# !echo file FHD0021b_3.MOV >  mylist.txt
# !echo file FHD0025.MOV >> mylist.txt
#!echo file "nextvideo" >> mylist.txt

#Concatenate Files
# !ffmpeg -f concat -i mylist.txt -c copy carrera_Burgueno.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
